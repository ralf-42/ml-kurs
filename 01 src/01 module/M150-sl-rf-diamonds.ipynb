# %% [markdown]
# <p><font size="6" color='grey'> <b>
# Machine Learning
# </b></font> </br></p>
# <p><font size="5" color='grey'> <b>
# Supervised Learning - Random Forest - Diamonds
# </b></font> </br></p>
#
# ---

# %% [markdown]
# ![diamond (Klein).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Bild von <a href="https://pixabay.com/de/users/colin00b-346653/?utm_source=link-attribution&amp;utm_medium=referral&amp;utm_campaign=image&amp;utm_content=1186139">Colin Behrens</a> auf <a href="https://pixabay.com/de//?utm_source=link-attribution&amp;utm_medium=referral&amp;utm_campaign=image&amp;utm_content=1186139">Pixabay</a>

# %% [markdown]
# # **1 <font color='orange'>|</font> Understand**
# ***

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Aufgabe verstehen</br>
# ✅ Daten sammeln</br>
# ✅ Statistische Analyse (Min, Max, Mean, Korrelation, ...)</br>
# ✅ Datenvisualisierung (Streudiagramm, Box-Plot, ...)</br>
# ✅ Prepare Schritte festlegen</br>

# %% [markdown]
# <p><font color='black' size="5">
# Warnungen ausstellen
# </font></p>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <p><font color='black' size="5">
# Anwendungsfall
# </font></p>
#
# ---
#
# Dieser klassische Datensatz enthält die Preise und andere Attribute von fast 54.000 Diamanten.
#
#
#
# [DataSet](https://www.openml.org/search?type=data&status=active&id=42225)
#
# [Info](https://www.kaggle.com/datasets/shivam2503/diamonds)

# %%
data_id = 42225
import pandas as pd
from sklearn.datasets import fetch_openml
df = fetch_openml(parser='auto', data_id=data_id)

# %%
label = 'price'
features = [n for n in df.frame.columns if n != label]

target = df.frame[label].copy()
data = df.frame[features].copy()

# %% [markdown]
# <p><font color='black' size="5">
# EDA (Exploratory Data Analysis) mit Pandas
# </font></p>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   x        53940 non-null  float64
#  7   y        53940 non-null  float64
#  8   z        53940 non-null  float64
# dtypes: category(3), float64(6)
# memory usage: 2.6 MB

# %%
data.describe().T
# Out:
#          count       mean       std   min    25%    50%    75%    max
# carat  53940.0   0.797940  0.474011   0.2   0.40   0.70   1.04   5.01
# depth  53940.0  61.749405  1.432621  43.0  61.00  61.80  62.50  79.00
# table  53940.0  57.457184  2.234491  43.0  56.00  57.00  59.00  95.00
# x      53940.0   5.731157  1.121761   0.0   4.71   5.70   6.54  10.74
# y      53940.0   5.734526  1.142135   0.0   4.72   5.71   6.54  58.90
# z      53940.0   3.538734  0.705699   0.0   2.91   3.53   4.04  31.80

# %%
data.groupby('cut').count()
# Out:
#            carat  color  clarity  depth  table      x      y      z
# cut
# Very Good  12082  12082    12082  12082  12082  12082  12082  12082
# Fair        1610   1610     1610   1610   1610   1610   1610   1610
# Good        4906   4906     4906   4906   4906   4906   4906   4906
# Ideal      21551  21551    21551  21551  21551  21551  21551  21551
# Premium    13791  13791    13791  13791  13791  13791  13791  13791

# %%
data.groupby('color').count()
# Out:
#        carat    cut  clarity  depth  table      x      y      z
# color
# D       6775   6775     6775   6775   6775   6775   6775   6775
# E       9797   9797     9797   9797   9797   9797   9797   9797
# F       9542   9542     9542   9542   9542   9542   9542   9542
# G      11292  11292    11292  11292  11292  11292  11292  11292
# H       8304   8304     8304   8304   8304   8304   8304   8304
# I       5422   5422     5422   5422   5422   5422   5422   5422
# J       2808   2808     2808   2808   2808   2808   2808   2808

# %% [markdown]
# <p><font color='black' size="5">
# EDA (Exploratory Data Analysis) mit Plotly
# </font></p>

# %%
import plotly.express as px
import plotly.subplots as sp

# %%
title_ = 'Depth'
b1 = px.box(data['depth'], title=title_, width=600, height=600)

title_ = 'Carat'
b2 = px.box(data['carat'], title=title_, width=600, height=600)

title_ = 'Table'
b3 = px.box(data['table'], title=title_, width=600, height=600)

fig = sp.make_subplots(rows=1, cols=3, subplot_titles=('Depth', 'Carat', 'Table'))

for trace in b1.data:
    fig.add_trace(trace, row=1, col=1)

for trace in b2.data:
    fig.add_trace(trace, row=1, col=2)

for trace in b3.data:
    fig.add_trace(trace, row=1, col=3)

# Layout anpassen
fig.update_layout(width=1000, height=500, title_text='Box-Plots')

# Plot anzeigen
fig.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # **2 <font color='orange'>|</font>  Prepare**
#
# ---

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Nicht benötigte Features löschen</br>
# ✅ Datentyp ermitteln/ändern</br>
# ✅ Duplikate ermitteln/löschen</br>
# ✅ Missing Values behandeln</br>
# ✅ Ausreißer behandeln</br>
# ✅ Kategorischer Features codieren</br>
# ✅ Numerischer Features skalieren</br>
# ✅ Dimensionalität reduzieren</br>
# ✅ Datensampling (Over-/Undersampling)</br>
# ✅ Feature-Engineering (neue Features schaffen)</br>
# ✅ Pipeline erstellen/konfigurieren</br>

# %% [markdown]
# <p><font color='black' size="5">
# Datentyp ermitteln
# </font></p>

# %%
all_col = data.columns
num_col = data.select_dtypes(include='number').columns
cat_col = data.select_dtypes(exclude='number').columns

# %% [markdown]
# <p><font color='black' size="5">
# Duplikate ermitteln
# </font></p>

# %%
duplicates = df.frame[df.frame.duplicated()]
print("Anzahl Duplicate: ", len(duplicates))
# print("Duplizierte Einträge:")
# print(duplicates)
# Out:
# Anzahl Duplicate:  146

# %% [markdown]
# <p><font color='black' size="5">
# Duplikate löschen
# </font></p>

# %%
col_names = data.columns

# %%
df.frame.drop_duplicates(subset=col_names, inplace=True)

# %%
target = df.frame[label].copy()
data = df.frame[features].copy()

# %% [markdown]
# <p><font color='black' size="5">
# Codierung
# </font></p>

# %%
from sklearn.preprocessing import OrdinalEncoder
cat_seq = [['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'],['J', 'I', 'H', 'G', 'F', 'E', 'D'], ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']]
data[cat_col] = OrdinalEncoder(categories=cat_seq).fit_transform(data[cat_col])

# %% [markdown]
# # **3 <font color='orange'>|</font>  Modeling**
# ---

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Train-Test-Split erstellen</br>
# ✅ Modellauswahl treffen</br>
# ✅ Pipeline erweitern/konfigurieren</br>
# ✅ Training durchführen</br>

# %% [markdown]
# <p><font color='black' size="5">
# Train-Test-Set
# </font></p>

# %%
from sklearn.model_selection import train_test_split
data_train, data_test, target_train, target_test = train_test_split(data, target, test_size=0.3, random_state=42)
data_train.shape, data_test.shape, target_train.shape, target_test.shape
# Out:
# ((37516, 9), (16079, 9), (37516,), (16079,))

# %% [markdown]
#  <p><font color='black' size="5">
# Modellauswahl & Training
# </font></p>

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=500, max_features=5, max_depth=4, min_samples_leaf=5)
model.fit(data_train, target_train)
# Out:
# RandomForestRegressor(max_depth=4, max_features=5, min_samples_leaf=5,
#                       n_estimators=500)

# %% [markdown]
# # **4 <font color='orange'>|</font> Evaluate**
# ---

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Prognose (Train, Test) erstellen</br>
# ✅ Modellgüte prüfen</br>
# ✅ Residuenanalyse erstellen</br>
# ✅ Feature Importance/Selektion prüfen</br>
# ✅ Robustheitstest erstellen</br>
# ✅ Modellinterpretation erstellen</br>
# ✅ Sensitivitätsanalyse erstellen</br>
# ✅ Kommunikation (Key Takeaways)</br>

# %% [markdown]
# <p><font color='black' size="5">
# Prediction
# </font></p>

# %%
target_train_pred = model.predict(data_train)
target_test_pred = model.predict(data_test)

# %% [markdown]
# <p><font color='black' size="5">
# Bestimmtheitsmass
# </font></p>

# %%
from sklearn.metrics import r2_score
r2 = r2_score(target_train, target_train_pred)
print(f'Modell: {model} -- Train -- Bestimmtheitsmass: {r2:5.2f}' )
# Out:
# Modell: RandomForestRegressor(max_depth=4, max_features=5, min_samples_leaf=5,
#                       n_estimators=500) -- Train -- Bestimmtheitsmass:  0.93

# %%
r2 = r2_score(target_test, target_test_pred)
print(f'Modell: {model} -- Test -- Bestimmtheitsmass: {r2:5.2f}' )
# Out:
# Modell: RandomForestRegressor(max_depth=4, max_features=5, min_samples_leaf=5,
#                       n_estimators=500) -- Test -- Bestimmtheitsmass:  0.93

# %% [markdown]
# <p><font color='black' size="5">
# Mean Absolut Error
# </font></p>

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(target_test, target_test_pred)
print(f'Modell: {model} -- Test -- Mean Absolute Error: {mae:5.2f}' )
# Out:
# Modell: RandomForestRegressor(max_depth=4, max_features=5, min_samples_leaf=5,
#                       n_estimators=500) -- Test -- Mean Absolute Error: 598.89

# %% [markdown]
# <p><font color='black' size="5">
# Aufbau Analysewürfel
# </font></p>

# %%
# Übernahme der Testdaten
cube = data_test.copy()
cube.reset_index(inplace=True)

# Übernahem Target real & predict
cube['real'] = pd.DataFrame(target_test.values, columns=['real'])
cube['predict'] = pd.DataFrame(target_test_pred, columns=['predict'])

# Erstellung 2D Features über Dimensionsreduktion PCA - unsupervised
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca = pca.fit_transform(data_test)
pca_df = pd.DataFrame(pca)

# Cube um pca erweitern
cube['PCA1'] = pca_df[0]
cube['PCA2'] = pca_df[1]

# %% [markdown]
# <p><font color='black' size="5">
# Visualisierung real vs predict
# </font></p>

# %%
import plotly.express as px
import plotly.subplots as sp

# %%
# Boxplot
title_ = 'Boxplot real vs predict'
px.box(cube[['real', 'predict']], title=title_, width=600, height=600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="
,3103,5765,829,1956,1367,1729,11447,1845,2072,1088,421,631,2810,4201,2818,17672,1906,600,540,5174,5026,5871,5458,3892,559,2792,580,1741,844,2238,2339,514,1881,686,4655,395,1088,1624,11133,2528,2617,776,821,2192,4190,1821,4077,18113,4503,15718,953,1778,4762,16193,6580,1832,1189,538,16368,4783,8333,2662,868,1087,14863,675,874,2669,7727,3404,364,571,3011,2198,3482,8886,548,2118,7227,872,2117,945,4789,4601,2085,4381,2829,4685,4250,555,1967,1643,610,1041,2208,4074,5703,949,984,3016,3247,8637,8176,8637,2572,15137,1666,442,2239,3668,1757,1238,780,1243,2814,999,15847,5769,782,4269,2485,5424,552,2052,2164,2660,1046,1068,18766,606,4243,7550,2527,7389,738,851,4572,5759,1633,3053,4232,4543,5889,524,6089,480,4113,5586,3344,746,14428,1200,773,6709,1200,936,4146,1723,3251,7840,534,11175,778,921,17068,4241,504,3787, ...

# %% [markdown]
# <p><font color='black' size="5">
# Fehlerhafte Vorhersagen
# </font></p>

# %%
cube['abs_Abw%'] = abs((cube['real'] - cube['predict']) / cube['real'] *100)
# %precision 3
cube.head(10).style.format("{:,.1f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_88f5f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88f5f_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_88f5f_level0_col1" class="col_heading level0 col1" >carat</th>
#       <th id="T_88f5f_level0_col2" class="col_heading level0 col2" >cut</th>
#       <th id="T_88f5f_level0_col3" class="col_heading level0 col3" >color</th>
#       <th id="T_88f5f_level0_col4" class="col_heading level0 col4" >clarity</th>
#       <th id="T_88f5f_level0_col5" class="col_heading level0 col5" >depth</th>
#       <th id="T_88f5f_level0_col6" class="col_heading level0 col6" >table</th>
#       <th id="T_88f5f_level0_col7" class="col_heading level0 col7" >x</th>
#       <th id="T_88f5f_level0_col8" class="col_heading level0 col8" >y</th>
#       <th id="T_88f5f_level0_col9" class="col_heading level0 col9" >z</th>
#       <th id="T_88f5f_level0_col10" class="col_heading level0 col10" >real</th>
#       <th id="T_88f5f_level0_col11" class="col_heading level0 col11" >predict</th>
#       <th id="T_88f5f_level0_col12" class="col_heading level0 col12" >PCA1</th>
#       <th id="T_88f5f_level0_col13" class="col_heading level0 col13" >PCA2</th>
#       <th id="T_88f5f_level0_col14" class="col_heading level0 col14" >abs_Abw%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88f5f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88f5f_row0_col0" class="data row0 col0" >9,272.0</td>
#       <td id="T_88f5f_row0_col1" class="data row0 col1" >1.0</td>
#       <td id="T_88f5f_row0_col2" class="data row0 col2" >1.0</td>
#       <td id="T_88f5f_row0_col3" class="data row0 col3" >5.0</td>
#       <td id="T_88f5f_row0_col4" class="data row0 col4" >2.0</td>
#       <td id="T_88f5f_row0_col5" class="data row0 col5" >64.5</td>
#       <td id="T_88f5f_row0_col6" class="data row0 col6" >56.0</td>
#       <td id="T_88f5f_row0_col7" class="data row0 col7" >6.2</td>
#       <td id="T_88f5f_row0_col8" class="data row0 col8" >6.3</td>
#       <td id="T_88f5f_row0_col9" class="data row0 col9" >4.0</td>
#       <td id="T_88f5f_row0_col10" class="data row0 col10" >4,563.0</td>
#       <td id="T_88f5f_row0_col11" class="data row0 col11" >4,811.5</td>
#       <td id="T_88f5f_row0_col12" class="data row0 col12" >-0.7</td>
#       <td id="T_88f5f_row0_col13" class="data row0 col13" >-1.6</td>
#       <td id="T_88f5f_row0_col14" class="data row0 col14" >5.4</td>
#     </tr>
#     <tr>
#       <th id="T_88f5f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_88f5f_row1_col0" class="data row1 col0" >53,442.0</td>
#       <td id="T_88f5f_row1_col1" class="data row1 col1" >0.9</td>
#       <td id="T_88f5f_row1_col2" class="data row1 col2" >2.0</td>
#       <td id="T_88f5f_row1_col3" class="data row1 col3" >6.0</td>
#       <td id="T_88f5f_row1_col4" class="data row1 col4" >0.0</td>
#       <td id="T_88f5f_row1_col5" class="data row1 col5" >63.0</td>
#       <td id="T_88f5f_row1_col6" class="data row1 col6" >58.0</td>
#       <td id="T_88f5f_row1_col7" class="data row1 col7" >6.1</td>
#       <td id="T_88f5f_row1_col8" class="data row1 col8" >6.2</td>
#       <td id="T_88f5f_row1_col9" class="data row1 col9" >3.9</td>
#       <td id="T_88f5f_row1_col10" class="data row1 col10" >2,674.0</td>
#       <td id="T_88f5f_row1_col11" class="data row1 col11" >3,831.4</td>
#       <td id="T_88f5f_row1_col12" class="data row1 col12" >1.4</td>
#       <td id="T_88f5f_row1_col13" class="data row1 col13" >-0.5</td>
#       <td id="T_88f5f_row1_col14" class="data row1 col14" >43.3</td>
#     </tr>
#     <tr>
#       <th id="T_88f5f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_88f5f_row2_col0" class="data row2 col0" >36,985.0</td>
#       <td id="T_88f5f_row2_col1" class="data row2 col1" >0.4</td>
#       <td id="T_88f5f_row2_col2" class="data row2 col2" >4.0</td>
#       <td id="T_88f5f_row2_col3" class="data row2 col3" >5.0</td>
#       <td id="T_88f5f_row2_col4" class="data row2 col4" >3.0</td>
#       <td id="T_88f5f_row2_col5" class="data row2 col5" >61.9</td>
#       <td id="T_88f5f_row2_col6" class="data row2 col6" >57.0</td>
#       <td id="T_88f5f_row2_col7" class="data row2 col7" >4.7</td>
#       <td id="T_88f5f_row2_col8" class="data row2 col8" >4.6</td>
#       <td id="T_88f5f_row2_col9" class="data row2 col9" >2.9</td>
#       <td id="T_88f5f_row2_col10" class="data row2 col10" >963.0</td>
#       <td id="T_88f5f_row2_col11" class="data row2 col11" >934.6</td>
#       <td id="T_88f5f_row2_col12" class="data row2 col12" >-1.4</td>
#       <td id="T_88f5f_row2_col13" class="data row2 col13" >1.6</td>
#       <td id="T_88f5f_row2_col14" class="data row2 col14" >2.9</td>
#     </tr>
#     <tr>
#       <th id="T_88f5f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_88f5f_row3_col0" class="data row3 col0" >17,690.0</td>
#       <td id="T_88f5f_row3_col1" class="data row3 col1" >0.9</td>
#       <td id="T_88f5f_row3_col2" class="data row3 col2" >2.0</td>
#       <td id="T_88f5f_row3_col3" class="data row3 col3" >5.0</td>
#       <td id="T_88f5f_row3_col4" class="data row3 col4" >5.0</td>
#       <td id="T_88f5f_row3_col5" class="data row3 col5" >61.1</td>
#       <td id="T_88f5f_row3_col6" class="data row3 col6" >61.0</td>
#       <td id="T_88f5f_row3_col7" class="data row3 col7" >6.2</td>
#       <td id="T_88f5f_row3_col8" class="data row3 col8" >6.2</td>
#       <td id="T_88f5f_row3_col9" class="data row3 col9" >3.8</td>
#       <td id="T_88f5f_row3_col10" class="data row3 col10" >7,131.0</td>
#       <td id="T_88f5f_row3_col11" class="data row3 col11" >4,285.1</td>
#       <td id="T_88f5f_row3_col12" class="data row3 col12" >2.9</td>
#       <td id="T_88f5f_row3_col13" class="data row3 col13" >2.6</td>
#       <td id="T_88f5f_row3_col14" class="data row3 col14" >39.9</td>
#     </tr>
#     <tr>
#       <th id="T_88f5f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_88f5f_row4_col0" class="data row4 col0" >14,696.0</td>
#       <td id="T_88f5f_row4_col1" class="data row4 col1" >1.0</td>
#       <td id="T_88f5f_row4_col2" class="data row4 col2" >2.0</td>
#       <td id="T_88f5f_row4_col3" class="data row4 col3" >4.0</td>
#       <td id="T_88f5f_row4_col4" class="data row4 col4" >3.0</td>
#       <td id="T_88f5f_row4_col5" class="data row4 col5" >58.7</td>
#       <td id="T_88f5f_row4_col6" class="data row4 col6" >62.0</td>
#       <td id="T_88f5f_row4_col7" class="data row4 col7" >6.5</td>
#       <td id="T_88f5f_row4_col8" class="data row4 col8" >6.6</td>
#       <td id="T_88f5f_row4_col9" class="data row4 col9" >3.9</td>
#       <td id="T_88f5f_row4_col10" class="data row4 col10" >5,929.0</td>
#       <td id="T_88f5f_row4_col11" class="data row4 col11" >6,399.7</td>
#       <td id="T_88f5f_row4_col12" class="data row4 col12" >5.0</td>
#       <td id="T_88f5f_row4_col13" class="data row4 col13" >2.1</td>
#       <td id="T_88f5f_row4_col14" class="data row4 col14" >7.9</td>
#     </tr>
#     <tr>
#       <th id="T_88f5f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_88f5f_row5_col0" class="data row5 col0" >23,217.0</td>
#       <td id="T_88f5f_row5_col1" class="data row5 col1" >1.1</td>
#       <td id="T_88f5f_row5_col2" class="data row5 col2" >4.0</td>
#       <td id="T_88f5f_row5_col3" class="data row5 col3" >4.0</td>
#       <td id="T_88f5f_row5_col4" class="data row5 col4" >6.0</td>
#       <td id="T_88f5f_row5_col5" class="data row5 col5" >60.1</td>
#       <td id="T_88f5f_row5_col6" class="data row5 col6" >60.0</td>
#       <td id="T_88f5f_row5_col7" class="data row5 col7" >6.8</td>
#       <td id="T_88f5f_row5_col8" class="data row5 col8" >6.8</td>
#       <td id="T_88f5f_row5_col9" class="data row5 col9" >4.1</td>
#       <td id="T_88f5f_row5_col10" class="data row5 col10" >11,226.0</td>
#       <td id="T_88f5f_row5_col11" class="data row5 col11" >8,986.7</td>
#       <td id="T_88f5f_row5_col12" class="data row5 col12" >1.9</td>
#       <td id="T_88f5f_row5_col13" class="data row5 col13" >1.8</td>
#       <td id="T_88f5f_row5_col14" class="data row5 col14" >19.9</td>

# %%
cube.describe().T
# Out:
#             count          mean           std         min           25%  \
