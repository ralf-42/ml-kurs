# %% [markdown]
# <p><font size="6" color='grey'> <b>
# Machine Learning
# </b></font> </br></p>
# <p><font size="5" color='grey'> <b>
# GridSearch - Model - DataSet
# </b></font> </br></p>
#
# ---

# %% [markdown]
# ![search (Klein).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Bild von <a href="https://pixabay.com/de/users/firmbee-663163/?utm_source=link-attribution&amp;utm_medium=referral&amp;utm_campaign=image&amp;utm_content=621033">Firmbee</a> auf <a href="https://pixabay.com/de//?utm_source=link-attribution&amp;utm_medium=referral&amp;utm_campaign=image&amp;utm_content=621033">Pixabay</a>

# %% [markdown]
# # **1 <font color='orange'>|</font> Understand**
# ***

# %% [markdown]
# <p><font color='black' size="5">
# Warnungen ausstellen
# </font></p>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <p><font color='black' size="5">
# Anwendungsfall
# </font></p>
#
# ---
#
# Erstellen Sie eine Rastersuche (GridSearch) für eines der bereits erstellten Jupyter Notebooks.

# %% [markdown]
# <p><font color='black' size="5">
# EDA (Exploratory Data Analysis) mit Pandas
# </font></p>

# %%
data.info()

# %%
data.describe().T

# %% [markdown]
# # **2 <font color='orange'>|</font>  Prepare**
#
# ---

# %% [markdown]
# # **3 <font color='orange'>|</font> Modeling**
# ---

# %% [markdown]
# # **4 <font color='orange'>|</font> Evaluate**
# ---

# %% [markdown]
# # **5 <font color='orange'>|</font> Deploy**
# ---
