# %% [markdown]
# <p><font size="6" color='grey'> <b>
# Machine Learning
# </b></font> </br></p>
# <p><font size="5" color='grey'> <b>
# Save/Load - Model - DataSet
# </b></font> </br></p>
#
# ---

# %% [markdown]
# ![courier (Klein).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Bild von <a href="https://pixabay.com/de/users/skitterphoto-324082/?utm_source=link-attribution&amp;utm_medium=referral&amp;utm_campaign=image&amp;utm_content=1214227">Rudy and Peter Skitterians</a> auf <a href="https://pixabay.com/de//?utm_source=link-attribution&amp;utm_medium=referral&amp;utm_campaign=image&amp;utm_content=1214227">Pixabay</a>

# %% [markdown]
# # **1 <font color='orange'>|</font> Understand**
# ***

# %% [markdown]
# <p><font color='black' size="5">
# Warnungen ausstellen
# </font></p>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <p><font color='black' size="5">
# Anwendungsfall
# </font></p>
#
# ---
#
# Testen Sie für ein bereits erstelltes Modell die Funktionen `Save` und `Load` aus. Nach dem Laden des trainierten Modells erstellen Sie eine Abfrage/Prognose.

# %% [markdown]
# <p><font color='black' size="5">
# EDA (Exploratory Data Analysis) mit Pandas
# </font></p>

# %%
data.info()

# %%
data.describe().T

# %% [markdown]
# # **2 <font color='orange'>|</font>  Prepare**
#
# ---

# %% [markdown]
# # **3 <font color='orange'>|</font>  Modeling**
# ---

# %% [markdown]
# # **4 <font color='orange'>|</font> Evaluate**
# ---

# %% [markdown]
# # **5 <font color='orange'>|</font> Deploy**
# ---
