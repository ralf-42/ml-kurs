# %% [markdown]
# <p><font size="6" color='grey'> <b>
# Machine Learning
# </b></font> </br></p>
# <p><font size="5" color='grey'> <b>
# Cross Validation - Model - DataSet
# </b></font> </br></p>
#
# ---

# %% [markdown]
# ![microscope (Klein).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Bild von <a href="https://pixabay.com/de/users/publicdomainpictures-14/?utm_source=link-attribution&amp;utm_medium=referral&amp;utm_campaign=image&amp;utm_content=275984">PublicDomainPictures</a> auf <a href="https://pixabay.com/de//?utm_source=link-attribution&amp;utm_medium=referral&amp;utm_campaign=image&amp;utm_content=275984">Pixabay</a>

# %% [markdown]
# # **1 <font color='orange'>|</font> Understand**
# ---

# %% [markdown]
# <p><font color='black' size="5">
# Warnungen ausschalten
# </font></p>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <p><font color='black' size="5">
# Anwendungsfall
# </font></p>
#
# ---
#
# Erstellen Sie eine Kreuzvalidierung für eines der bereits erstellten Jupyter Notebooks.

# %%
# Einlesen der Daten

# %% [markdown]
# <p><font color='black' size="5">
# EDA (Exploratory Data Analysis) mit Pandas
# </font></p>

# %%
data.info()

# %%
data.describe().T

# %%
target.value_counts()

# %% [markdown]
# # **2 <font color='orange'>|</font> Prepare**
# ---

# %% [markdown]
# # **3 <font color='orange'>|</font> Modeling**
# ---

# %% [markdown]
# # **4 <font color='orange'>|</font> Evaluate**
# ---

# %% [markdown]
# # **5 <font color='orange'>|</font> Deploy**
# ---
