# %% [markdown]
# <p><font size="6" color='grey'> <b>
# Machine Learning
# </b></font> </br></p>
# <p><font size="5" color='grey'> <b>
# Pipeline - Model - DataSet
# </b></font> </br></p>
#
# ---

# %% [markdown]
# ![pipeline (Klein).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Bild von <a href="https://pixabay.com/de/users/robzor-840419/?utm_source=link-attribution&amp;utm_medium=referral&amp;utm_campaign=image&amp;utm_content=681175">Robson Machado</a> auf <a href="https://pixabay.com/de//?utm_source=link-attribution&amp;utm_medium=referral&amp;utm_campaign=image&amp;utm_content=681175">Pixabay</a>

# %% [markdown]
# # **1 <font color='orange'>|</font> Understand**
# ***

# %% [markdown]
# <p><font color='black' size="5">
# Warnungen ausstellen
# </font></p>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <p><font color='black' size="5">
# Anwendungsfall
# </font></p>
#
# ---
#
# Erstellen Sie eine Pipeline mit einem der nachfolgenden DataSets. Die Pipeline sollte mindestens Coding, Scaling und Modeling enthalten.

# %% [markdown]
# + car_crashes: https://www.kaggle.com/fivethirtyeight/fivethirtyeight-bad-drivers-dataset
# + diamonds: https://ggplot2.tidyverse.org/reference/diamonds.html
# + dowjones: https://fred.stlouisfed.org/series/M1109BUSM293NNBR
# + geyser: https://stat.ethz.ch/R-manual/R-devel/library/datasets/html/faithful.html
# + mpg: https://data.world/dataman-udit/cars-data
# + penguins: https://github.com/allisonhorst/penguins
# + seaice: https://nsidc.org/arcticseaicenews/sea-ice-tools/
# + taxis: https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page
# + tips: https://rdrr.io/cran/reshape2/man/tips.html
# + titanic: https://www.kaggle.com/c/titanic/data

# %%
import pandas as pd
import seaborn
df = seaborn.load_dataset("...")

# %%
label = '...'
features = [n for n in df.columns if n != label]

# %%
data = df[features].copy()
target = df[label].copy()

# %% [markdown]
# <p><font color='black' size="5">
# EDA (Exploratory Data Analysis) mit Pandas
# </font></p>

# %%
data.info()

# %%
data.describe().T

# %% [markdown]
# # **2 <font color='orange'>|</font>  Prepare**
#
# ---

# %% [markdown]
# <p><font color='black' size="5">
# Import & Konfiguration Pipeline Anzeige
# </font></p>

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn import set_config
set_config(display='diagram')

# %% [markdown]
# <p><font color='black' size="5">
# Datentyp ermitteln
# </font></p>

# %% [markdown]
# <p><font color='black' size="5">
# Missing Values & Codierung der kategorialen Features
# </font></p>

# %% [markdown]
# <p><font color='black' size="5">
# Missing Values & Skalierung der numerischen Features
# </font></p>

# %% [markdown]
# <p><font color='black' size="5">
# ColumnTransformer
# </font></p>

# %% [markdown]
# # **3 <font color='orange'>|</font>  Modeling**
# ---

# %% [markdown]
# <p><font color='black' size="5">
# Train-Test-Set
# </font></p>

# %% [markdown]
#  <p><font color='black' size="5">
# Modell-, Featureauswahl & Training
# </font>

# %% [markdown]
# # **4 <font color='orange'>|</font> Evaluate**
# ---

# %% [markdown]
# <p><font color='black' size="5">
# Prognose
# </font></p>

# %% [markdown]
# <p><font color='black' size="5">
# Accuracy oder Bestimmtheitsmass
# </font></p>

# %% [markdown]
# <p><font color='black' size="5">
# Analyse von Zwischenschritten einer Pipeline
# </font></p>

# %% [markdown]
# # **5 <font color='orange'>|</font> Deploy**
# ---
